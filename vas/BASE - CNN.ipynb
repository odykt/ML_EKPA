# %% [markdown]
# ## Εισαγωγικά

# %%
#IMPORTS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn

# %%
# Set random seed for reproducibility
import random
import os
SEED = 56
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

from sklearn.utils import check_random_state
check_random_state(SEED)
# Out:
# RandomState(MT19937) at 0x1E398AB6640

# %%
# Use cuda if present
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %% [markdown]
# ## Β. Προεπεξεργασία και Εξερεύνηση Δεδομένων

# %% [markdown]
# ### 1. Εξερευνητική Ανάλυση Δεδομένων (EDA)

# %%
# Load data with pickling enabled
data = np.load(r'C:\\Users\\vasgk\\Desktop\\Μηχανική μάθηση\\Data\\breastmnist_224.npz', allow_pickle=True)

# Inspect the keys in the dataset
print("Keys in the dataset:", data.files)
print("Keys in the dataset are formatted as such:", data.files)
print("Shape of file contents: (no of contents, dimensions (224x224))")

# Print the shape of each file in the original npz file
for key in data.files:
    print(f"{key}: {data[key].shape}")
# Out:
# Keys in the dataset: ['train_images', 'train_labels', 'val_images', 'val_labels', 'test_images', 'test_labels']
# Keys in the dataset are formatted as such: ['train_images', 'train_labels', 'val_images', 'val_labels', 'test_images', 'test_labels']
# Shape of file contents: (no of contents, dimensions (224x224))
# train_images: (546, 224, 224)
# train_labels: (546, 1)
# val_images: (78, 224, 224)
# val_labels: (78, 1)
# test_images: (156, 224, 224)
# test_labels: (156, 1)

# %%
# Convert the data into a DataFrame
# Flatten the images and combine them with labels
train_images_flat = data['train_images'].reshape(len(data['train_images']), -1)  # Flatten 224x224 images
df_train = pd.DataFrame(train_images_flat)
df_train['Label'] = data['train_labels']

# Repeat for validation and test data, but in reverse order because the dataset's ratio is reversed
val_images_flat = data['test_images'].reshape(len(data['test_images']), -1)
df_val = pd.DataFrame(val_images_flat)
df_val['Label'] = data['test_labels']

test_images_flat = data['val_images'].reshape(len(data['val_images']), -1)
df_test = pd.DataFrame(test_images_flat)
df_test['Label'] = data['val_labels']

# Split the data into features and labels for the rest of the code
x_train = df_train.drop(columns=['Label']).values  
y_train = df_train['Label'].values.ravel()  
x_val = df_val.drop(columns=['Label']).values 
y_val = df_val['Label'].values.ravel()  
x_test = df_test.drop(columns=['Label']).values  
y_test = df_test['Label'].values.ravel()  

# save the DataFrames to CSV files SO I DONT HAVE TO RELOAD THEM EVERY TIME
#df_train.to_csv('train_data.csv', index=False)
#df_val.to_csv('val_data.csv', index=False)
#df_test.to_csv('test_data.csv', index=False)

# %%
# Load data, IF YOU DONT WANT TO RELOAD THE DATA, COMMENT THIS OUT
df_train = pd.read_csv('train_data.csv')
df_val = pd.read_csv('val_data.csv')
df_test = pd.read_csv('test_data.csv')

# %%
# Check the shapes of the arrays and DataFrames
print("Train images shape:", x_train.shape)
print("Train labels shape:", y_train.shape)
print("Missing values in training data:", df_train.isnull().sum().sum())
print()
print("Validation images shape:", x_val.shape)
print("Validation labels shape:", y_val.shape)
print("Missing values in validation data:", df_val.isnull().sum().sum())
print()
print("Test images shape:", x_test.shape)
print("Test labels shape:", y_test.shape)
print("Missing values in test data:", df_test.isnull().sum().sum())

"""# Display the first few rows of each DataFrame
print("Training DataFrame:")
print(df_train.head())

print("Validation DataFrame:")
print(df_val.head())

print("Test DataFrame:")
print(df_test.head())
"""

print("\n")
# Calculate the total number of images
num_train = len(x_train)
num_val = len(x_val)
num_test = len(x_test)
total_images = num_train + num_val + num_test
print(f"Total number of images: {total_images}, ({num_train} ({num_train /total_images * 100:.2f}%) train), ({num_val} ({num_val/total_images * 100:.2f}%) val), {num_test} ({num_test/total_images * 100:.2f})% test)")
print(f"Number of positives: {np.sum(y_train == 1)} train, {np.sum(y_val == 1)} val, {np.sum(y_test == 1)} test")
print(f"Percentage of positives: {np.mean(y_train == 1) * 100:.2f}% train, {np.mean(y_val == 1) * 100:.2f}% val, {np.mean(y_test == 1) * 100:.2f}% test")
print(f"Number of negatives: {np.sum(y_train == 0)} train, {np.sum(y_val == 0)} val, {np.sum(y_test == 0)} test")
print(f"Percentage of negatives: {np.mean(y_train == 0) * 100:.2f}% train, {np.mean(y_val == 0) * 100:.2f}% val, {np.mean(y_test == 0) * 100:.2f}% test")


# Display the first X images

images = data['train_images']
labels = data['train_labels']

plt.figure(figsize=(10, 10))
for i in range(10):
    plt.subplot(2, 5, i + 1)  # Create a 2x5 grid for 10 images
    plt.imshow(images[i], cmap='gray')
    plt.title(f"{'normal ' if labels[i] == 1 else 'malignant'}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Train images shape: (546, 50176)
# Train labels shape: (546,)
# Missing values in training data: 0
#
# Validation images shape: (156, 50176)
# Validation labels shape: (156,)
# Missing values in validation data: 0
#
# Test images shape: (78, 50176)
# Test labels shape: (78,)
# Missing values in test data: 0
#
#
# Total number of images: 780, (546 (70.00%) train), (156 (20.00%) val), 78 (10.00)% test)
# Number of positives: 399 train, 114 val, 57 test
# Percentage of positives: 73.08% train, 73.08% val, 73.08% test
# Number of negatives: 147 train, 42 val, 21 test
# Percentage of negatives: 26.92% train, 26.92% val, 26.92% test

# %%
#PLOTS
# Convert the relevant data from the NpzFile object into a pandas DataFrame
# Create a row of 3 plots for the label distributions
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot for training data
df_train['Label'].value_counts().rename(index={1: 'normal', 0: 'malignant'}).plot(kind='bar', ax=axes[0], color=['blue', 'orange'])
axes[0].set_title('Training Data Label Distribution')
axes[0].set_xlabel('Labels')
axes[0].set_ylabel('Count')
axes[0].set_xticklabels(['normal(1)', 'malignant(0)'], rotation=0)  # Set horizontal labels

# Plot for validation data
df_val['Label'].value_counts().rename(index={1: 'normal', 0: 'malignant'}).plot(kind='bar', ax=axes[1], color=['blue', 'orange'])
axes[1].set_title('Validation Data Label Distribution')
axes[1].set_xlabel('Labels')
axes[1].set_ylabel('Count')
axes[1].set_xticklabels(['normal(1)', 'malignant(0)'], rotation=0)  # Set horizontal labels


# Plot for test data
df_test['Label'].value_counts().rename(index={1: 'normal', 0: 'malignant'}).plot(kind='bar', ax=axes[2], color=['blue', 'orange'])
axes[2].set_title('Test Data Label Distribution')
axes[2].set_xlabel('Labels')
axes[2].set_ylabel('Count')
axes[2].set_xticklabels(['normal(1)', 'malignant(0)'], rotation=0)  # Set horizontal labels


# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Ισως να το σβήσω αυτό, δεν είναι απαραίτητο
# Find extreme values (min and max) in the image datasets

print("Extreme values in train_images:")
print("  Min:", np.min(data['train_images']))
print("  Max:", np.max(data['train_images']))

print("Extreme values in val_images:")
print("  Min:", np.min(data['val_images']))
print("  Max:", np.max(data['val_images']))

print("Extreme values in test_images:")
print("  Min:", np.min(data['test_images']))
print("  Max:", np.max(data['test_images']))

# For all images combined
all_images = np.concatenate([data['train_images'], data['val_images'], data['test_images']])
print("Extreme values in all images:")
print("  Min:", np.min(all_images))
print("  Max:", np.max(all_images))
# Out:
# Extreme values in train_images:
#   Min: 0
#   Max: 255
# Extreme values in val_images:
#   Min: 0
#   Max: 255
# Extreme values in test_images:
#   Min: 0
#   Max: 255
# Extreme values in all images:
#   Min: 0
#   Max: 255

# %%
# Visualize images with extreme pixel values

# Find min and max pixel values in all images
min_val = np.min(all_images)
max_val = np.max(all_images)

# Find the indices of images containing the min and max values
min_img_idx = np.where(np.any(all_images == min_val, axis=(1,2)))[0][0]
max_img_idx = np.where(np.any(all_images == max_val, axis=(1,2)))[0][0]

# Show the image with the minimum pixel value
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(all_images[min_img_idx], cmap='gray')
plt.title(f'Image with min pixel value ({min_val})')
plt.axis('off')

# Show the image with the maximum pixel value
plt.subplot(1, 2, 2)
plt.imshow(all_images[max_img_idx], cmap='gray')
plt.title(f'Image with max pixel value ({max_val})')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Detect outlier images based on mean pixel value

# Compute mean pixel value for each image
image_means = all_images.reshape(all_images.shape[0], -1).mean(axis=1)

# Calculate thresholds for outliers (e.g., using 3 standard deviations from the mean)
mean_val = np.mean(image_means)
std_val = np.std(image_means)
lower_threshold = mean_val - 3 * std_val
upper_threshold = mean_val + 3 * std_val

# Find indices of outlier images
outlier_indices = np.where((image_means < lower_threshold) | (image_means > upper_threshold))[0]

print(f"Number of outlier images (mean pixel value): {len(outlier_indices)}")

# Optionally, visualize the outlier images
if len(outlier_indices) > 0:
    plt.figure(figsize=(15, 3))
    for i, idx in enumerate(outlier_indices[:5]):  # Show up to 5 outliers
        plt.subplot(1, 5, i + 1)
        plt.imshow(all_images[idx], cmap='gray')
        plt.title(f"Mean: {image_means[idx]:.2f}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()
else:
    print("No outlier images found.")
# Out:
# Number of outlier images (mean pixel value): 1

# %% [markdown]
# The outlier doesn't seem corrupted, I will keep it since it's just an image with very different brightness and that may be the cause for being considered an outlier

# %% [markdown]
# ### 2. Προεπεξεργασία Δεδομένων

# %% [markdown]
# #### α. Χειρισμός ακραίων τιμών: δεν υπάρχουν ελλειπούσες τιμές και επιλέγω να διατηρήσω το outlier

# %% [markdown]
# #### β. Κανονικοποίηση/Τυποποίηση χαρακτηριστικών:
# Για την κανονικοποίηση/τυποποίηση των χαρακτηριστικών, εφαρμόστηκε η μέθοδος Standard Scaling (Z-score normalization), ώστε κάθε χαρακτηριστικό να έχει μέση τιμή 0 και τυπική απόκλιση 1. Η επιλογή αυτή έγινε επειδή οι αλγόριθμοι PCA, LDA και Logistic Regression είναι ευαίσθητοι στην κλίμακα των χαρακτηριστικών. Η κατανομή των τιμών πριν και μετά την τυποποίηση απεικονίστηκε με ιστογράμματα, ενώ παρατηρήθηκε ότι η τυποποίηση βελτιώνει τη διακριτική ικανότητα και τη σύγκλιση των αλγορίθμων.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler

# Standardize features
scaler = StandardScaler()
x_train_std = scaler.fit_transform(train_images_flat)
x_val_std = scaler.transform(val_images_flat)  
x_test_std = scaler.transform(test_images_flat)

# %%
# Visualize pixel value distributions before and after Standard Scaling

# Flatten the training images
flattened_images = x_train.reshape(x_train.shape[0], -1)

# Before scaling
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(flattened_images.flatten(), bins=50, color='skyblue', alpha=0.7)
plt.title('Pixel Value Distribution (Before Scaling)')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

# After scaling
scaler = StandardScaler()
flattened_images_std = scaler.fit_transform(flattened_images)
plt.subplot(1, 2, 2)
plt.hist(flattened_images_std.flatten(), bins=50, color='orange', alpha=0.7)
plt.title('Pixel Value Distribution (After Standard Scaling)')
plt.xlabel('Scaled Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
print("Mean pixel value:", np.mean(data['train_images']))
print("Standard deviation of pixel values:", np.std(data['train_images']))

print("Mean pixel value after scaling:", np.mean(flattened_images_std))
print("Standard deviation of pixel values after scaling:", np.std(flattened_images_std))
# Out:
# Mean pixel value: 83.56028899154099
# Standard deviation of pixel values: 55.95538071677974
# Mean pixel value after scaling: 2.960428742496773e-17
# Standard deviation of pixel values after scaling: 1.0

# %% [markdown]
# Ανάλυση επίδρασης:(το αναφέρω και πιο πάνω) scaling improves convergence and performance for most machine learning algorithms, especially those based on distances or projections.

# %% [markdown]
# #### γ. Επιλογή και μετασχηματισμός χαρακτηριστικών:

# %% [markdown]
# 1. Αφαίρεση χαρακτηριστικών με χαμηλή διακύμανση (Remove low-variance features)
# You can use VarianceThreshold from scikit-learn to remove features (pixels) with very low variance, which are unlikely to be useful for classification

# %%
# Calculate variances
variances = x_train_std.var(axis=0)
plt.hist(variances, bins=50)
plt.title("Feature Variance Distribution")
plt.xlabel("Variance")
plt.ylabel("Number of Features")
plt.show()

# %%
print("Min variance:", variances.min())
print("Max variance:", variances.max())
# Out:
# Min variance: 0.9999999999999898
# Max variance: 1.0000000000000102

# %%
from sklearn.feature_selection import VarianceThreshold

# Remove features with variance below a threshold (e.g., 0.01)
selector = VarianceThreshold(threshold=0.01)
X_train_var = selector.fit_transform(x_train_std)
X_val_var = selector.transform(x_val_std)
X_test_var = selector.transform(x_test_std)

print("Original shape:", x_train_std.shape)
print("After variance thresholding:", X_train_var.shape)
# Out:
# Original shape: (546, 50176)
# After variance thresholding: (546, 50176)

# %% [markdown]
# 2. Δημιουργία νέων χαρακτηριστικών (Feature engineering)
# For images, common new features include mean, standard deviation, or other statistics per image. Example:

# %%
# Example: Add mean and std of pixel values as new features
train_means = x_train.reshape(x_train.shape[0], -1).mean(axis=1).reshape(-1, 1)
train_stds = x_train.reshape(x_train.shape[0], -1).std(axis=1).reshape(-1, 1)
X_train_fe = np.hstack([X_train_var, train_means, train_stds])

# Repeat for validation and test sets
val_means = x_val.reshape(x_val.shape[0], -1).mean(axis=1).reshape(-1, 1)
val_stds = x_val.reshape(x_val.shape[0], -1).std(axis=1).reshape(-1, 1)
X_val_fe = np.hstack([X_val_var, val_means, val_stds])

test_means = x_test.reshape(x_test.shape[0], -1).mean(axis=1).reshape(-1, 1)
test_stds = x_test.reshape(x_test.shape[0], -1).std(axis=1).reshape(-1, 1)
X_test_fe = np.hstack([X_test_var, test_means, test_stds])

# %% [markdown]
# 3. Εφαρμογή πολυωνυμικών χαρακτηριστικών (Polynomial features)
# You can use polynomial features if you want to capture interactions between pixels (not common for images, but possible for tabular data):

# %%
from sklearn.preprocessing import PolynomialFeatures

# Example: Use only a subset of features for demonstration (e.g., first 10)
poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train_var[:, :10])
print("Shape with polynomial features:", X_train_poly.shape)
# Out:
# Shape with polynomial features: (546, 65)

# %% [markdown]
# 4. Αιτιολόγηση των μετασχηματισμών
# Αφαίρεση χαμηλής διακύμανσης: Αφαιρεί άχρηστα χαρακτηριστικά που δεν προσφέρουν πληροφορία.
# Feature engineering: Προσθέτει στατιστικά που μπορεί να βοηθήσουν στη διάκριση των κατηγοριών.
# Πολυωνυμικά χαρακτηριστικά: Επιτρέπουν στο μοντέλο να μάθει μη γραμμικές σχέσεις, αν και για εικόνες συνήθως δεν χρησιμοποιούνται λόγω του μεγάλου αριθμού χαρακτηριστικών.
# Συμπέρασμα:
# Εφαρμόζοντας αυτές τις τεχνικές, βελτιώνετε την ποιότητα των χαρακτηριστικών και ενισχύετε τη δυνατότητα του μοντέλου να μάθει σημαντικά μοτίβα από τα δεδομένα σας.
# Αιτιολογήστε κάθε βήμα με βάση το πρόβλημα και τα αποτελέσματα που παρατηρείτε.

# %% [markdown]
# ## Ε. Βαθιά Νευρωνικά Δίκτυα

# %% [markdown]
# ## CNN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Μετατροπή ετικετών σε αριθμούς
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# Βεβαιωθείτε ότι τα x_train, x_val, x_test έχουν σχήμα [num_samples, height, width]
# Αν έχουν σχήμα [num_samples, features], μετατρέψτε τα σε εικόνες (π.χ. 224x224 ή 128x128 ή 64x64)
# Εδώ υποθέτουμε ότι height και width είναι γνωστά, π.χ. 224
height = width = int(np.sqrt(x_train.shape[1])) if len(x_train.shape) == 2 else x_train.shape[1]

if len(x_train.shape) == 2:
    X_train_tensor = torch.tensor(x_train.reshape(-1, height, width), dtype=torch.float32).unsqueeze(1)
    X_val_tensor = torch.tensor(x_val.reshape(-1, height, width), dtype=torch.float32).unsqueeze(1)
    X_test_tensor = torch.tensor(x_test.reshape(-1, height, width), dtype=torch.float32).unsqueeze(1)
else:
    X_train_tensor = torch.tensor(x_train, dtype=torch.float32).unsqueeze(1)
    X_val_tensor = torch.tensor(x_val, dtype=torch.float32).unsqueeze(1)
    X_test_tensor = torch.tensor(x_test, dtype=torch.float32).unsqueeze(1)

# Δημιουργία TensorDataset και DataLoader
train_data = TensorDataset(X_train_tensor, torch.tensor(y_train_encoded, dtype=torch.long))
val_data = TensorDataset(X_val_tensor, torch.tensor(y_val_encoded, dtype=torch.long))
test_data = TensorDataset(X_test_tensor, torch.tensor(y_test_encoded, dtype=torch.long))

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Ορισμός του CNN μοντέλου
class CNN(nn.Module):
    def __init__(self, num_classes):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)  # 1: κανάλι εικόνας (grayscale)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(2)

        # Dynamically compute the size after conv/pool layers
        with torch.no_grad():
            dummy = torch.zeros(1, 1, height, width)
            x = self.relu(self.conv1(dummy))
            x = self.maxpool(x)
            x = self.relu(self.conv2(x))
            x = self.maxpool(x)
            x = self.relu(self.conv3(x))
            x = self.maxpool(x)
            flat_features = x.view(1, -1).shape[1]

        self.fc1 = nn.Linear(flat_features, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.maxpool(x)
        x = self.relu(self.conv2(x))
        x = self.maxpool(x)
        x = self.relu(self.conv3(x))
        x = self.maxpool(x)
        x = x.view(x.size(0), -1)  # Flatten το tensor
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Ορισμός του μοντέλου, κριτηρίου και optimizer
model = CNN(num_classes=len(np.unique(y_train)))
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Εκπαίδευση του μοντέλου
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_accuracy = 100 * correct / total
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.2f}%")

# Αξιολόγηση του μοντέλου στο Validation Set
model.eval()
val_correct = 0
val_total = 0
with torch.no_grad():
    for inputs, labels in val_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        val_total += labels.size(0)
        val_correct += (predicted == labels).sum().item()

val_accuracy = 100 * val_correct / val_total
print(f"Validation Accuracy: {val_accuracy:.2f}%")

# Αξιολόγηση του μοντέλου στο Test Set
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = 100 * test_correct / test_total
print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Epoch 1/10, Loss: 84.1731, Accuracy: 60.99%
# Epoch 2/10, Loss: 0.5868, Accuracy: 73.08%
# Epoch 3/10, Loss: 0.5474, Accuracy: 74.91%
# Epoch 4/10, Loss: 0.5840, Accuracy: 74.91%
# Epoch 5/10, Loss: 0.4870, Accuracy: 76.92%
# Epoch 6/10, Loss: 0.3489, Accuracy: 84.43%
# Epoch 7/10, Loss: 0.2970, Accuracy: 87.00%
# Epoch 8/10, Loss: 0.3699, Accuracy: 82.05%
# Epoch 9/10, Loss: 0.3108, Accuracy: 86.45%
# Epoch 10/10, Loss: 0.2869, Accuracy: 90.29%
# Validation Accuracy: 62.82%
# Test Accuracy: 67.95%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt

# Μετατροπή ετικετών σε αριθμούς
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# Μετατροπή των εικόνων σε PyTorch tensors με σωστό shape [num_samples, 1, height, width]
height, width = 224, 224  # ή βάλτε το σωστό μέγεθος εικόνας αν είναι διαφορετικό
X_train_tensor = torch.tensor(x_train.reshape(-1, 1, height, width), dtype=torch.float32)
X_val_tensor = torch.tensor(x_val.reshape(-1, 1, height, width), dtype=torch.float32)
X_test_tensor = torch.tensor(x_test.reshape(-1, 1, height, width), dtype=torch.float32)

# Δημιουργία TensorDataset και DataLoader
train_data = TensorDataset(X_train_tensor, torch.tensor(y_train_encoded, dtype=torch.long))
val_data = TensorDataset(X_val_tensor, torch.tensor(y_val_encoded, dtype=torch.long))
test_data = TensorDataset(X_test_tensor, torch.tensor(y_test_encoded, dtype=torch.long))

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Ορισμός του CNN μοντέλου με Dropout και διαφορετικές συναρτήσεις ενεργοποίησης
class CNN(nn.Module):
    def __init__(self, num_classes, activation_fn='ReLU'):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(128 * 28 * 28, 512)  # Προσαρμογή ανάλογα με το μέγεθος των εικόνων (224x224 -> 28x28)
        self.fc2 = nn.Linear(512, num_classes)
        self.dropout = nn.Dropout(0.5)  # Dropout για κανονικοποίηση

        if activation_fn == 'ReLU':
            self.activation = nn.ReLU()
        elif activation_fn == 'LeakyReLU':
            self.activation = nn.LeakyReLU(0.1)
        elif activation_fn == 'ELU':
            self.activation = nn.ELU()
        else:
            raise ValueError(f"Unknown activation function: {activation_fn}")

        self.maxpool = nn.MaxPool2d(2)

    def forward(self, x):
        x = self.activation(self.conv1(x))
        x = self.maxpool(x)
        x = self.activation(self.conv2(x))
        x = self.maxpool(x)
        x = self.activation(self.conv3(x))
        x = self.maxpool(x)
        x = x.view(x.size(0), -1)  # Flatten το tensor
        x = self.dropout(self.activation(self.fc1(x)))  # Dropout πριν από το πλήρως συνδεδεμένο επίπεδο
        x = self.fc2(x)
        return x

# Εφαρμογή Regularization μέσω L2 (Weight Decay) στον Adam optimizer
def create_model_and_optimizer(activation_fn='ReLU', lr=0.001, weight_decay=0.01):
    model = CNN(num_classes=len(np.unique(y_train)), activation_fn=activation_fn)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    return model, criterion, optimizer

# Ορισμός της διαδικασίας εκπαίδευσης με αποθήκευση του καλύτερου μοντέλου
def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=20):
    train_losses, train_accuracies = [], []
    val_losses, val_accuracies = [], []  
    
    best_val_accuracy = 0.0
    best_model_state_dict = None  # Για να αποθηκεύσουμε το state dict του καλύτερου μοντέλου

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_accuracy = 100 * correct / total
        train_losses.append(running_loss / len(train_loader))
        train_accuracies.append(train_accuracy)

        # Αξιολόγηση στο Validation Set
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_accuracy = 100 * val_correct / val_total
        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(val_accuracy)

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracies[-1]:.2f}%, Val Loss: {val_losses[-1]:.4f}, Val Accuracy: {val_accuracies[-1]:.2f}%")

        # Αν η ακρίβεια στο validation set είναι καλύτερη, αποθηκεύουμε το μοντέλο
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            best_model_state_dict = model.state_dict()  # Αποθήκευση του state_dict του καλύτερου μοντέλου

    # Αποθήκευση του καλύτερου μοντέλου στο τέλος της εκπαίδευσης
    if best_model_state_dict is not None:
        torch.save(best_model_state_dict, 'best_model.pth')  # Αποθήκευση του καλύτερου μοντέλου

    return train_losses, train_accuracies, val_losses, val_accuracies


# Ορισμός υπερπαραμέτρων για τον πειραματισμό
learning_rates = [0.001, 0.0001]
activation_functions = ['ReLU', 'LeakyReLU', 'ELU']
weight_decays = [0.01, 0.001]

# Πειραματισμός με διαφορετικούς συνδυασμούς
for lr in learning_rates:
    for activation_fn in activation_functions:
        for wd in weight_decays:
            print(f"\nTraining with lr={lr}, activation_fn={activation_fn}, weight_decay={wd}")
            model, criterion, optimizer = create_model_and_optimizer(activation_fn, lr, wd)
            train_losses, train_accuracies, val_losses, val_accuracies = train_model(model, criterion, optimizer, train_loader, val_loader)

            # Οπτικοποίηση των καμπυλών μάθησης
            plt.figure(figsize=(12, 5))

            # Καμπύλες Απώλειας
            plt.subplot(1, 2, 1)
            plt.plot(train_losses, label='Train Loss')
            plt.plot(val_losses, label='Validation Loss')
            plt.title(f'Loss for lr={lr}, activation_fn={activation_fn}, wd={wd}')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.legend()

            # Καμπύλες Ακρίβειας
            plt.subplot(1, 2, 2)
            plt.plot(train_accuracies, label='Train Accuracy')
            plt.plot(val_accuracies, label='Validation Accuracy')
            plt.title(f'Accuracy for lr={lr}, activation_fn={activation_fn}, wd={wd}')
            plt.xlabel('Epochs')
            plt.ylabel('Accuracy')
            plt.legend()

            plt.show()
# Out:
# Training with lr=0.001, activation_fn=ReLU, weight_decay=0.01
# Epoch 1/20, Train Loss: 54.9026, Train Accuracy: 62.27%, Val Loss: 0.5339, Val Accuracy: 73.08%
# Epoch 2/20, Train Loss: 0.6999, Train Accuracy: 71.06%, Val Loss: 0.5452, Val Accuracy: 73.08%
# Epoch 3/20, Train Loss: 0.5046, Train Accuracy: 72.89%, Val Loss: 0.5231, Val Accuracy: 72.44%
# Epoch 4/20, Train Loss: 0.4222, Train Accuracy: 79.85%, Val Loss: 0.5396, Val Accuracy: 70.51%
# Epoch 5/20, Train Loss: 0.3675, Train Accuracy: 81.87%, Val Loss: 0.5628, Val Accuracy: 71.15%
# Epoch 6/20, Train Loss: 0.3682, Train Accuracy: 82.23%, Val Loss: 0.6399, Val Accuracy: 73.08%
# Epoch 7/20, Train Loss: 0.2231, Train Accuracy: 89.38%, Val Loss: 0.6560, Val Accuracy: 70.51%
# Epoch 8/20, Train Loss: 0.1900, Train Accuracy: 93.41%, Val Loss: 0.7046, Val Accuracy: 69.23%
# Epoch 9/20, Train Loss: 0.2378, Train Accuracy: 90.48%, Val Loss: 0.7435, Val Accuracy: 76.92%
# Epoch 10/20, Train Loss: 0.1896, Train Accuracy: 94.14%, Val Loss: 1.1938, Val Accuracy: 76.92%
# Epoch 11/20, Train Loss: 0.1594, Train Accuracy: 93.41%, Val Loss: 0.8986, Val Accuracy: 75.00%
# Epoch 12/20, Train Loss: 0.1031, Train Accuracy: 95.97%, Val Loss: 0.8946, Val Accuracy: 73.72%
# Epoch 13/20, Train Loss: 0.1143, Train Accuracy: 96.34%, Val Loss: 1.0827, Val Accuracy: 76.92%
# Epoch 14/20, Train Loss: 0.0926, Train Accuracy: 97.44%, Val Loss: 0.9198, Val Accuracy: 78.21%
# Epoch 15/20, Train Loss: 0.0512, Train Accuracy: 98.72%, Val Loss: 1.1926, Val Accuracy: 77.56%
# Epoch 16/20, Train Loss: 0.0467, Train Accuracy: 99.08%, Val Loss: 0.9657, Val Accuracy: 75.00%
# Epoch 17/20, Train Loss: 0.0376, Train Accuracy: 99.27%, Val Loss: 0.9498, Val Accuracy: 76.92%
# Epoch 18/20, Train Loss: 0.0336, Train Accuracy: 99.45%, Val Loss: 1.4781, Val Accuracy: 75.64%
# Epoch 19/20, Train Loss: 0.0350, Train Accuracy: 98.90%, Val Loss: 1.3731, Val Accuracy: 76.28%
# Epoch 20/20, Train Loss: 0.0477, Train Accuracy: 98.72%, Val Loss: 1.1723, Val Accuracy: 79.49%
# Training with lr=0.001, activation_fn=ReLU, weight_decay=0.001
# Epoch 1/20, Train Loss: 85.7273, Train Accuracy: 62.64%, Val Loss: 0.8873, Val Accuracy: 73.08%
# Epoch 2/20, Train Loss: 0.6360, Train Accuracy: 73.99%, Val Loss: 0.5398, Val Accuracy: 73.08%
# Epoch 3/20, Train Loss: 0.5920, Train Accuracy: 74.73%, Val Loss: 0.5692, Val Accuracy: 73.72%
# Epoch 4/20, Train Loss: 0.4925, Train Accuracy: 78.21%, Val Loss: 0.4842, Val Accuracy: 75.00%
# Epoch 5/20, Train Loss: 0.3612, Train Accuracy: 82.97%, Val Loss: 0.5045, Val Accuracy: 73.72%
# Epoch 6/20, Train Loss: 0.3250, Train Accuracy: 86.45%, Val Loss: 0.5323, Val Accuracy: 71.79%
# Epoch 7/20, Train Loss: 0.2978, Train Accuracy: 88.46%, Val Loss: 0.6875, Val Accuracy: 73.72%
# Epoch 8/20, Train Loss: 0.2634, Train Accuracy: 89.74%, Val Loss: 0.6374, Val Accuracy: 73.72%
# Epoch 9/20, Train Loss: 0.2334, Train Accuracy: 90.66%, Val Loss: 0.8897, Val Accuracy: 75.00%
# Epoch 10/20, Train Loss: 0.2501, Train Accuracy: 89.93%, Val Loss: 0.6186, Val Accuracy: 76.92%
# Epoch 11/20, Train Loss: 0.1494, Train Accuracy: 94.32%, Val Loss: 0.6194, Val Accuracy: 77.56%
# Epoch 12/20, Train Loss: 0.1492, Train Accuracy: 94.51%, Val Loss: 0.6680, Val Accuracy: 82.05%
# Epoch 13/20, Train Loss: 0.0822, Train Accuracy: 97.07%, Val Loss: 0.7803, Val Accuracy: 77.56%
# Epoch 14/20, Train Loss: 0.0506, Train Accuracy: 97.99%, Val Loss: 1.0710, Val Accuracy: 76.28%
# Epoch 15/20, Train Loss: 0.0676, Train Accuracy: 98.53%, Val Loss: 0.8665, Val Accuracy: 78.21%
# Epoch 16/20, Train Loss: 0.0647, Train Accuracy: 97.44%, Val Loss: 0.8859, Val Accuracy: 79.49%
# Epoch 17/20, Train Loss: 0.0597, Train Accuracy: 97.80%, Val Loss: 1.4597, Val Accuracy: 75.64%
# Epoch 18/20, Train Loss: 0.1026, Train Accuracy: 96.34%, Val Loss: 0.7863, Val Accuracy: 78.21%
# Epoch 19/20, Train Loss: 0.0639, Train Accuracy: 97.99%, Val Loss: 0.9874, Val Accuracy: 79.49%
# Epoch 20/20, Train Loss: 0.0791, Train Accuracy: 97.62%, Val Loss: 0.8045, Val Accuracy: 77.56%
# Training with lr=0.001, activation_fn=LeakyReLU, weight_decay=0.01
# Epoch 1/20, Train Loss: 200.1347, Train Accuracy: 57.69%, Val Loss: 2.2639, Val Accuracy: 75.00%
# Epoch 2/20, Train Loss: 4.7181, Train Accuracy: 68.13%, Val Loss: 12.0113, Val Accuracy: 30.13%
# Epoch 3/20, Train Loss: 7.1526, Train Accuracy: 64.29%, Val Loss: 4.4580, Val Accuracy: 73.72%
# Epoch 4/20, Train Loss: 3.7575, Train Accuracy: 67.03%, Val Loss: 2.5587, Val Accuracy: 73.72%
# Epoch 5/20, Train Loss: 1.5387, Train Accuracy: 70.51%, Val Loss: 0.5283, Val Accuracy: 82.05%
# Epoch 6/20, Train Loss: 1.1540, Train Accuracy: 71.98%, Val Loss: 1.4452, Val Accuracy: 75.64%
# Epoch 7/20, Train Loss: 1.1484, Train Accuracy: 74.54%, Val Loss: 0.4656, Val Accuracy: 81.41%
# Epoch 8/20, Train Loss: 0.8279, Train Accuracy: 73.08%, Val Loss: 0.4228, Val Accuracy: 83.33%
# Epoch 9/20, Train Loss: 0.5215, Train Accuracy: 77.29%, Val Loss: 0.4061, Val Accuracy: 86.54%
# Epoch 10/20, Train Loss: 0.4319, Train Accuracy: 79.49%, Val Loss: 0.3904, Val Accuracy: 84.62%
# Epoch 11/20, Train Loss: 0.5479, Train Accuracy: 78.75%, Val Loss: 0.8460, Val Accuracy: 76.28%
# Epoch 12/20, Train Loss: 0.6456, Train Accuracy: 76.19%, Val Loss: 0.5125, Val Accuracy: 75.64%
# Epoch 13/20, Train Loss: 0.5378, Train Accuracy: 78.57%, Val Loss: 0.6738, Val Accuracy: 70.51%
# Epoch 14/20, Train Loss: 0.5784, Train Accuracy: 78.39%, Val Loss: 0.3931, Val Accuracy: 83.97%
# Epoch 15/20, Train Loss: 0.3139, Train Accuracy: 84.98%, Val Loss: 0.4325, Val Accuracy: 80.77%
# Epoch 16/20, Train Loss: 0.3402, Train Accuracy: 82.78%, Val Loss: 0.6566, Val Accuracy: 79.49%
# Epoch 17/20, Train Loss: 0.2590, Train Accuracy: 87.91%, Val Loss: 0.6912, Val Accuracy: 76.92%
# Epoch 18/20, Train Loss: 0.2510, Train Accuracy: 90.84%, Val Loss: 0.4193, Val Accuracy: 87.18%
# Epoch 19/20, Train Loss: 0.1714, Train Accuracy: 92.67%, Val Loss: 0.3787, Val Accuracy: 83.33%
# Epoch 20/20, Train Loss: 0.2103, Train Accuracy: 92.67%, Val Loss: 0.4505, Val Accuracy: 85.90%
# Training with lr=0.001, activation_fn=LeakyReLU, weight_decay=0.001
# Epoch 1/20, Train Loss: 104.7887, Train Accuracy: 60.81%, Val Loss: 6.7391, Val Accuracy: 73.08%
# Epoch 2/20, Train Loss: 3.6515, Train Accuracy: 67.22%, Val Loss: 1.8224, Val Accuracy: 76.92%
# Epoch 3/20, Train Loss: 1.6600, Train Accuracy: 68.50%, Val Loss: 0.5271, Val Accuracy: 81.41%
# Epoch 4/20, Train Loss: 0.8646, Train Accuracy: 70.15%, Val Loss: 0.4326, Val Accuracy: 82.69%
# Epoch 5/20, Train Loss: 0.7337, Train Accuracy: 74.73%, Val Loss: 0.4795, Val Accuracy: 82.05%
# Epoch 6/20, Train Loss: 1.1571, Train Accuracy: 73.26%, Val Loss: 1.0655, Val Accuracy: 75.00%
# Epoch 7/20, Train Loss: 0.7506, Train Accuracy: 76.92%, Val Loss: 1.9463, Val Accuracy: 39.10%
# Epoch 8/20, Train Loss: 1.1373, Train Accuracy: 67.77%, Val Loss: 0.5720, Val Accuracy: 81.41%
# Epoch 9/20, Train Loss: 0.6039, Train Accuracy: 78.57%, Val Loss: 1.4223, Val Accuracy: 45.51%
# Epoch 10/20, Train Loss: 0.9046, Train Accuracy: 73.81%, Val Loss: 0.5330, Val Accuracy: 79.49%
# Epoch 11/20, Train Loss: 0.6821, Train Accuracy: 75.46%, Val Loss: 0.5380, Val Accuracy: 83.33%
# Epoch 12/20, Train Loss: 0.4353, Train Accuracy: 81.32%, Val Loss: 0.3937, Val Accuracy: 83.33%
# Epoch 13/20, Train Loss: 0.3624, Train Accuracy: 83.15%, Val Loss: 1.0251, Val Accuracy: 73.72%
# Epoch 14/20, Train Loss: 0.3641, Train Accuracy: 84.43%, Val Loss: 0.4365, Val Accuracy: 83.33%
# Epoch 15/20, Train Loss: 0.2533, Train Accuracy: 88.10%, Val Loss: 0.5380, Val Accuracy: 78.85%
# Epoch 16/20, Train Loss: 0.2126, Train Accuracy: 91.03%, Val Loss: 0.4392, Val Accuracy: 83.97%
# Epoch 17/20, Train Loss: 0.1961, Train Accuracy: 92.31%, Val Loss: 0.6828, Val Accuracy: 75.64%
# Epoch 18/20, Train Loss: 0.2621, Train Accuracy: 88.83%, Val Loss: 0.5452, Val Accuracy: 83.33%
# Epoch 19/20, Train Loss: 0.1670, Train Accuracy: 92.67%, Val Loss: 0.4592, Val Accuracy: 85.26%
# Epoch 20/20, Train Loss: 0.1825, Train Accuracy: 93.22%, Val Loss: 0.4779, Val Accuracy: 84.62%
# Training with lr=0.001, activation_fn=ELU, weight_decay=0.01
# Epoch 1/20, Train Loss: 77.3770, Train Accuracy: 59.71%, Val Loss: 17.8317, Val Accuracy: 73.08%
# Epoch 2/20, Train Loss: 23.2665, Train Accuracy: 63.37%, Val Loss: 8.0307, Val Accuracy: 75.64%
# Epoch 3/20, Train Loss: 5.0223, Train Accuracy: 65.75%, Val Loss: 0.5851, Val Accuracy: 78.85%
# Epoch 4/20, Train Loss: 0.8707, Train Accuracy: 69.60%, Val Loss: 0.5794, Val Accuracy: 67.95%
# Epoch 5/20, Train Loss: 0.7588, Train Accuracy: 63.55%, Val Loss: 0.6587, Val Accuracy: 74.36%
# Epoch 6/20, Train Loss: 0.7173, Train Accuracy: 65.57%, Val Loss: 0.5108, Val Accuracy: 75.64%
# Epoch 7/20, Train Loss: 0.6718, Train Accuracy: 67.40%, Val Loss: 0.4931, Val Accuracy: 76.28%
# Epoch 8/20, Train Loss: 0.6757, Train Accuracy: 68.68%, Val Loss: 0.5428, Val Accuracy: 75.00%
# Epoch 9/20, Train Loss: 0.6211, Train Accuracy: 68.50%, Val Loss: 0.5112, Val Accuracy: 79.49%
# Epoch 10/20, Train Loss: 0.6314, Train Accuracy: 69.78%, Val Loss: 0.4832, Val Accuracy: 78.21%
# Epoch 11/20, Train Loss: 0.6176, Train Accuracy: 65.20%, Val Loss: 0.4903, Val Accuracy: 79.49%
# Epoch 12/20, Train Loss: 0.5661, Train Accuracy: 67.58%, Val Loss: 0.4850, Val Accuracy: 77.56%
# Epoch 13/20, Train Loss: 0.5423, Train Accuracy: 71.79%, Val Loss: 0.5290, Val Accuracy: 77.56%
# Epoch 14/20, Train Loss: 0.6244, Train Accuracy: 71.79%, Val Loss: 0.4852, Val Accuracy: 77.56%
# Epoch 15/20, Train Loss: 0.6341, Train Accuracy: 66.30%, Val Loss: 0.5324, Val Accuracy: 73.08%
# Epoch 16/20, Train Loss: 0.7008, Train Accuracy: 63.00%, Val Loss: 0.5853, Val Accuracy: 73.08%
# Epoch 17/20, Train Loss: 0.6377, Train Accuracy: 67.95%, Val Loss: 0.5442, Val Accuracy: 73.08%
# Epoch 18/20, Train Loss: 0.6686, Train Accuracy: 67.40%, Val Loss: 0.5358, Val Accuracy: 73.08%
# Epoch 19/20, Train Loss: 0.6009, Train Accuracy: 68.68%, Val Loss: 0.5108, Val Accuracy: 73.08%
# Epoch 20/20, Train Loss: 0.5958, Train Accuracy: 70.70%, Val Loss: 0.5008, Val Accuracy: 73.08%
# Training with lr=0.001, activation_fn=ELU, weight_decay=0.001
# Epoch 1/20, Train Loss: 104.8588, Train Accuracy: 61.90%, Val Loss: 10.9176, Val Accuracy: 73.72%
# Epoch 2/20, Train Loss: 3.2366, Train Accuracy: 61.54%, Val Loss: 0.6236, Val Accuracy: 74.36%
# Epoch 3/20, Train Loss: 0.7917, Train Accuracy: 69.05%, Val Loss: 0.6829, Val Accuracy: 73.08%
# Epoch 4/20, Train Loss: 0.6942, Train Accuracy: 67.22%, Val Loss: 0.6064, Val Accuracy: 73.08%
# Epoch 5/20, Train Loss: 0.6359, Train Accuracy: 63.92%, Val Loss: 0.5855, Val Accuracy: 73.08%
# Epoch 6/20, Train Loss: 0.6354, Train Accuracy: 70.88%, Val Loss: 0.5716, Val Accuracy: 73.08%
# Epoch 7/20, Train Loss: 0.5849, Train Accuracy: 71.06%, Val Loss: 0.5572, Val Accuracy: 73.08%
# Epoch 8/20, Train Loss: 0.6162, Train Accuracy: 72.71%, Val Loss: 0.5560, Val Accuracy: 73.08%
# Epoch 9/20, Train Loss: 0.5642, Train Accuracy: 71.61%, Val Loss: 0.5452, Val Accuracy: 73.08%
# Epoch 10/20, Train Loss: 0.5921, Train Accuracy: 70.51%, Val Loss: 0.5510, Val Accuracy: 73.08%
# Epoch 11/20, Train Loss: 0.5709, Train Accuracy: 72.89%, Val Loss: 0.5695, Val Accuracy: 73.08%
# Epoch 12/20, Train Loss: 0.5977, Train Accuracy: 71.61%, Val Loss: 0.5458, Val Accuracy: 73.08%
# Epoch 13/20, Train Loss: 0.5725, Train Accuracy: 69.96%, Val Loss: 0.5404, Val Accuracy: 73.08%
# Epoch 14/20, Train Loss: 0.6475, Train Accuracy: 70.70%, Val Loss: 0.5838, Val Accuracy: 73.08%
# Epoch 15/20, Train Loss: 0.6742, Train Accuracy: 69.78%, Val Loss: 0.5821, Val Accuracy: 73.08%
# Epoch 16/20, Train Loss: 0.6129, Train Accuracy: 70.88%, Val Loss: 0.5823, Val Accuracy: 73.08%
# Epoch 17/20, Train Loss: 0.6018, Train Accuracy: 71.25%, Val Loss: 0.5843, Val Accuracy: 73.08%
# Epoch 18/20, Train Loss: 0.5874, Train Accuracy: 71.06%, Val Loss: 0.5852, Val Accuracy: 73.08%
# Epoch 19/20, Train Loss: 0.5964, Train Accuracy: 72.34%, Val Loss: 0.5832, Val Accuracy: 73.08%
# Epoch 20/20, Train Loss: 0.6297, Train Accuracy: 71.25%, Val Loss: 0.5835, Val Accuracy: 73.08%
# Training with lr=0.0001, activation_fn=ReLU, weight_decay=0.01
# Epoch 1/20, Train Loss: 11.0196, Train Accuracy: 63.19%, Val Loss: 1.8861, Val Accuracy: 73.72%
# Epoch 2/20, Train Loss: 0.7795, Train Accuracy: 70.33%, Val Loss: 0.4788, Val Accuracy: 73.08%
# Epoch 3/20, Train Loss: 0.4105, Train Accuracy: 78.75%, Val Loss: 0.4126, Val Accuracy: 80.77%
# Epoch 4/20, Train Loss: 0.3348, Train Accuracy: 89.01%, Val Loss: 0.3809, Val Accuracy: 85.26%
# Epoch 5/20, Train Loss: 0.2240, Train Accuracy: 92.31%, Val Loss: 0.4261, Val Accuracy: 80.77%
# Epoch 6/20, Train Loss: 0.1536, Train Accuracy: 95.60%, Val Loss: 0.4099, Val Accuracy: 82.05%
# Epoch 7/20, Train Loss: 0.0917, Train Accuracy: 97.44%, Val Loss: 0.4506, Val Accuracy: 82.05%
# Epoch 8/20, Train Loss: 0.0787, Train Accuracy: 97.62%, Val Loss: 0.4399, Val Accuracy: 85.26%
# Epoch 9/20, Train Loss: 0.0477, Train Accuracy: 99.82%, Val Loss: 0.5466, Val Accuracy: 83.33%
# Epoch 10/20, Train Loss: 0.0272, Train Accuracy: 99.63%, Val Loss: 0.5905, Val Accuracy: 83.97%
# Epoch 11/20, Train Loss: 0.0196, Train Accuracy: 99.82%, Val Loss: 0.5348, Val Accuracy: 83.97%
# Epoch 12/20, Train Loss: 0.0184, Train Accuracy: 99.82%, Val Loss: 0.4834, Val Accuracy: 84.62%
# Epoch 13/20, Train Loss: 0.0214, Train Accuracy: 99.63%, Val Loss: 0.4848, Val Accuracy: 84.62%
# Epoch 14/20, Train Loss: 0.0154, Train Accuracy: 100.00%, Val Loss: 0.5659, Val Accuracy: 83.97%
# Epoch 15/20, Train Loss: 0.0140, Train Accuracy: 100.00%, Val Loss: 0.5977, Val Accuracy: 85.26%
# Epoch 16/20, Train Loss: 0.0120, Train Accuracy: 99.82%, Val Loss: 0.6088, Val Accuracy: 85.26%
# Epoch 17/20, Train Loss: 0.0192, Train Accuracy: 99.45%, Val Loss: 0.5324, Val Accuracy: 85.26%
# Epoch 18/20, Train Loss: 0.0230, Train Accuracy: 99.63%, Val Loss: 0.4597, Val Accuracy: 84.62%
# Epoch 19/20, Train Loss: 0.0155, Train Accuracy: 99.82%, Val Loss: 0.5347, Val Accuracy: 83.97%
# Epoch 20/20, Train Loss: 0.0105, Train Accuracy: 99.82%, Val Loss: 0.5708, Val Accuracy: 85.90%
# Training with lr=0.0001, activation_fn=ReLU, weight_decay=0.001
# Epoch 1/20, Train Loss: 10.5626, Train Accuracy: 62.45%, Val Loss: 1.1373, Val Accuracy: 75.00%
# Epoch 2/20, Train Loss: 1.0717, Train Accuracy: 71.61%, Val Loss: 0.4937, Val Accuracy: 75.00%
# Epoch 3/20, Train Loss: 0.4730, Train Accuracy: 76.92%, Val Loss: 0.4754, Val Accuracy: 83.97%
# Epoch 4/20, Train Loss: 0.3719, Train Accuracy: 83.70%, Val Loss: 0.4159, Val Accuracy: 80.13%
# Epoch 5/20, Train Loss: 0.2780, Train Accuracy: 88.46%, Val Loss: 0.4206, Val Accuracy: 81.41%
# Epoch 6/20, Train Loss: 0.2179, Train Accuracy: 90.11%, Val Loss: 0.3992, Val Accuracy: 82.69%
# Epoch 7/20, Train Loss: 0.1379, Train Accuracy: 94.14%, Val Loss: 0.4536, Val Accuracy: 83.33%
# Epoch 8/20, Train Loss: 0.0822, Train Accuracy: 98.35%, Val Loss: 0.3878, Val Accuracy: 86.54%
# Epoch 9/20, Train Loss: 0.0607, Train Accuracy: 99.08%, Val Loss: 0.4036, Val Accuracy: 87.18%
# Epoch 10/20, Train Loss: 0.0455, Train Accuracy: 99.45%, Val Loss: 0.5509, Val Accuracy: 83.33%
# Epoch 11/20, Train Loss: 0.0402, Train Accuracy: 99.08%, Val Loss: 0.4728, Val Accuracy: 87.18%
# Epoch 12/20, Train Loss: 0.0241, Train Accuracy: 99.82%, Val Loss: 0.5076, Val Accuracy: 87.82%
# Epoch 13/20, Train Loss: 0.0284, Train Accuracy: 99.82%, Val Loss: 0.5076, Val Accuracy: 86.54%
# Epoch 14/20, Train Loss: 0.0130, Train Accuracy: 100.00%, Val Loss: 0.5685, Val Accuracy: 85.90%
# Epoch 15/20, Train Loss: 0.0091, Train Accuracy: 100.00%, Val Loss: 0.6541, Val Accuracy: 85.90%
# Epoch 16/20, Train Loss: 0.0103, Train Accuracy: 100.00%, Val Loss: 0.6085, Val Accuracy: 85.90%
# Epoch 17/20, Train Loss: 0.0212, Train Accuracy: 99.63%, Val Loss: 0.5598, Val Accuracy: 87.18%
# Epoch 18/20, Train Loss: 0.0281, Train Accuracy: 99.63%, Val Loss: 0.5131, Val Accuracy: 85.90%
# Epoch 19/20, Train Loss: 0.0086, Train Accuracy: 100.00%, Val Loss: 0.6409, Val Accuracy: 85.26%
# Epoch 20/20, Train Loss: 0.0045, Train Accuracy: 100.00%, Val Loss: 0.6927, Val Accuracy: 85.26%
# Training with lr=0.0001, activation_fn=LeakyReLU, weight_decay=0.01
# Epoch 1/20, Train Loss: 15.9453, Train Accuracy: 61.36%, Val Loss: 0.8405, Val Accuracy: 79.49%
# Epoch 2/20, Train Loss: 1.1165, Train Accuracy: 71.79%, Val Loss: 0.7517, Val Accuracy: 73.72%
# Epoch 3/20, Train Loss: 0.4224, Train Accuracy: 79.67%, Val Loss: 0.3942, Val Accuracy: 83.33%
# Epoch 4/20, Train Loss: 0.3107, Train Accuracy: 85.53%, Val Loss: 0.4305, Val Accuracy: 80.13%
# Epoch 5/20, Train Loss: 0.2303, Train Accuracy: 88.83%, Val Loss: 0.4608, Val Accuracy: 83.33%
# Epoch 6/20, Train Loss: 0.1549, Train Accuracy: 93.96%, Val Loss: 0.4301, Val Accuracy: 83.97%
# Epoch 7/20, Train Loss: 0.1471, Train Accuracy: 94.69%, Val Loss: 0.4802, Val Accuracy: 84.62%
# Epoch 8/20, Train Loss: 0.1286, Train Accuracy: 95.97%, Val Loss: 0.5433, Val Accuracy: 85.26%
# Epoch 9/20, Train Loss: 0.0612, Train Accuracy: 97.99%, Val Loss: 0.6209, Val Accuracy: 83.97%
# Epoch 10/20, Train Loss: 0.0476, Train Accuracy: 97.99%, Val Loss: 0.5257, Val Accuracy: 85.90%
# Epoch 11/20, Train Loss: 0.0354, Train Accuracy: 98.90%, Val Loss: 0.6582, Val Accuracy: 85.90%
# Epoch 12/20, Train Loss: 0.0169, Train Accuracy: 99.63%, Val Loss: 0.6195, Val Accuracy: 85.90%
# Epoch 13/20, Train Loss: 0.0147, Train Accuracy: 99.45%, Val Loss: 0.6606, Val Accuracy: 86.54%
# Epoch 14/20, Train Loss: 0.0117, Train Accuracy: 99.82%, Val Loss: 0.7232, Val Accuracy: 86.54%
# Epoch 15/20, Train Loss: 0.0056, Train Accuracy: 100.00%, Val Loss: 0.8708, Val Accuracy: 86.54%
# Epoch 16/20, Train Loss: 0.0126, Train Accuracy: 99.45%, Val Loss: 0.8598, Val Accuracy: 85.90%
# Epoch 17/20, Train Loss: 0.0036, Train Accuracy: 100.00%, Val Loss: 0.8534, Val Accuracy: 87.18%
# Epoch 18/20, Train Loss: 0.0032, Train Accuracy: 100.00%, Val Loss: 0.9133, Val Accuracy: 87.82%
# Epoch 19/20, Train Loss: 0.0043, Train Accuracy: 99.82%, Val Loss: 0.8384, Val Accuracy: 85.90%
# Epoch 20/20, Train Loss: 0.0055, Train Accuracy: 100.00%, Val Loss: 0.8102, Val Accuracy: 83.33%
# Training with lr=0.0001, activation_fn=LeakyReLU, weight_decay=0.001
# Epoch 1/20, Train Loss: 17.3769, Train Accuracy: 64.10%, Val Loss: 5.3984, Val Accuracy: 73.08%
# Epoch 2/20, Train Loss: 1.4664, Train Accuracy: 73.26%, Val Loss: 0.5746, Val Accuracy: 69.87%
# Epoch 3/20, Train Loss: 0.4667, Train Accuracy: 80.77%, Val Loss: 0.4339, Val Accuracy: 83.97%
# Epoch 4/20, Train Loss: 0.3441, Train Accuracy: 83.70%, Val Loss: 0.4143, Val Accuracy: 83.97%
# Epoch 5/20, Train Loss: 0.2232, Train Accuracy: 91.58%, Val Loss: 0.4013, Val Accuracy: 86.54%
# Epoch 6/20, Train Loss: 0.1460, Train Accuracy: 94.14%, Val Loss: 0.4278, Val Accuracy: 85.90%
# Epoch 7/20, Train Loss: 0.0978, Train Accuracy: 96.89%, Val Loss: 0.5093, Val Accuracy: 85.90%
# Epoch 8/20, Train Loss: 0.0505, Train Accuracy: 98.72%, Val Loss: 0.6035, Val Accuracy: 85.26%
# Epoch 9/20, Train Loss: 0.0319, Train Accuracy: 99.63%, Val Loss: 0.6254, Val Accuracy: 86.54%
# Epoch 10/20, Train Loss: 0.0316, Train Accuracy: 99.27%, Val Loss: 0.5799, Val Accuracy: 84.62%
# Epoch 11/20, Train Loss: 0.0223, Train Accuracy: 99.27%, Val Loss: 0.5619, Val Accuracy: 85.26%
# Epoch 12/20, Train Loss: 0.0205, Train Accuracy: 99.45%, Val Loss: 0.7597, Val Accuracy: 82.69%
# Epoch 13/20, Train Loss: 0.0211, Train Accuracy: 99.82%, Val Loss: 0.5562, Val Accuracy: 84.62%
# Epoch 14/20, Train Loss: 0.0129, Train Accuracy: 99.82%, Val Loss: 0.6583, Val Accuracy: 85.90%
# Epoch 15/20, Train Loss: 0.0166, Train Accuracy: 99.82%, Val Loss: 0.6524, Val Accuracy: 87.18%
# Epoch 16/20, Train Loss: 0.0138, Train Accuracy: 99.82%, Val Loss: 0.6295, Val Accuracy: 82.05%
# Epoch 17/20, Train Loss: 0.0175, Train Accuracy: 99.63%, Val Loss: 0.6347, Val Accuracy: 84.62%
# Epoch 18/20, Train Loss: 0.0051, Train Accuracy: 100.00%, Val Loss: 0.7069, Val Accuracy: 85.26%
# Epoch 19/20, Train Loss: 0.0046, Train Accuracy: 100.00%, Val Loss: 0.6786, Val Accuracy: 87.82%
# Epoch 20/20, Train Loss: 0.0020, Train Accuracy: 100.00%, Val Loss: 0.6920, Val Accuracy: 85.26%
# Training with lr=0.0001, activation_fn=ELU, weight_decay=0.01
# Epoch 1/20, Train Loss: 10.7060, Train Accuracy: 59.34%, Val Loss: 1.4252, Val Accuracy: 73.08%
# Epoch 2/20, Train Loss: 0.8166, Train Accuracy: 67.03%, Val Loss: 0.5511, Val Accuracy: 73.72%
# Epoch 3/20, Train Loss: 0.5828, Train Accuracy: 73.08%, Val Loss: 0.5435, Val Accuracy: 79.49%
# Epoch 4/20, Train Loss: 0.6042, Train Accuracy: 70.51%, Val Loss: 0.4439, Val Accuracy: 80.13%
# Epoch 5/20, Train Loss: 0.4572, Train Accuracy: 77.47%, Val Loss: 0.4185, Val Accuracy: 81.41%
# Epoch 6/20, Train Loss: 0.4199, Train Accuracy: 83.88%, Val Loss: 0.3778, Val Accuracy: 83.97%
# Epoch 7/20, Train Loss: 0.3877, Train Accuracy: 82.78%, Val Loss: 0.4014, Val Accuracy: 81.41%
# Epoch 8/20, Train Loss: 0.3472, Train Accuracy: 85.71%, Val Loss: 0.5406, Val Accuracy: 78.21%
# Epoch 9/20, Train Loss: 0.3242, Train Accuracy: 86.81%, Val Loss: 0.3659, Val Accuracy: 87.18%
# Epoch 10/20, Train Loss: 0.2898, Train Accuracy: 88.83%, Val Loss: 0.3672, Val Accuracy: 85.90%
# Epoch 11/20, Train Loss: 0.2414, Train Accuracy: 89.38%, Val Loss: 0.3682, Val Accuracy: 85.90%
# Epoch 12/20, Train Loss: 0.1819, Train Accuracy: 92.12%, Val Loss: 0.3581, Val Accuracy: 88.46%
# Epoch 13/20, Train Loss: 0.1801, Train Accuracy: 93.22%, Val Loss: 0.3885, Val Accuracy: 87.18%
# Epoch 14/20, Train Loss: 0.1579, Train Accuracy: 94.32%, Val Loss: 0.3797, Val Accuracy: 85.90%
# Epoch 15/20, Train Loss: 0.1559, Train Accuracy: 94.87%, Val Loss: 0.4369, Val Accuracy: 85.26%
# Epoch 16/20, Train Loss: 0.1827, Train Accuracy: 92.86%, Val Loss: 0.4002, Val Accuracy: 86.54%
# Epoch 17/20, Train Loss: 0.1110, Train Accuracy: 96.15%, Val Loss: 0.4179, Val Accuracy: 87.18%
# Epoch 18/20, Train Loss: 0.0952, Train Accuracy: 96.70%, Val Loss: 0.4407, Val Accuracy: 86.54%
# Epoch 19/20, Train Loss: 0.0744, Train Accuracy: 98.17%, Val Loss: 0.4630, Val Accuracy: 85.90%
# Epoch 20/20, Train Loss: 0.0594, Train Accuracy: 97.99%, Val Loss: 0.4453, Val Accuracy: 87.18%
# Training with lr=0.0001, activation_fn=ELU, weight_decay=0.001
# Epoch 1/20, Train Loss: 14.0618, Train Accuracy: 62.45%, Val Loss: 1.7065, Val Accuracy: 73.08%
# Epoch 2/20, Train Loss: 0.7199, Train Accuracy: 67.40%, Val Loss: 0.7359, Val Accuracy: 73.08%
# Epoch 3/20, Train Loss: 0.6358, Train Accuracy: 68.13%, Val Loss: 0.5542, Val Accuracy: 73.08%
# Epoch 4/20, Train Loss: 0.6249, Train Accuracy: 70.33%, Val Loss: 0.5304, Val Accuracy: 73.08%
# Epoch 5/20, Train Loss: 0.5869, Train Accuracy: 70.88%, Val Loss: 0.5426, Val Accuracy: 73.08%
# Epoch 6/20, Train Loss: 0.6088, Train Accuracy: 72.89%, Val Loss: 0.5304, Val Accuracy: 73.08%
# Epoch 7/20, Train Loss: 0.5426, Train Accuracy: 72.16%, Val Loss: 0.5299, Val Accuracy: 73.08%
# Epoch 8/20, Train Loss: 0.6501, Train Accuracy: 71.79%, Val Loss: 0.5049, Val Accuracy: 73.08%
# Epoch 9/20, Train Loss: 0.7109, Train Accuracy: 60.81%, Val Loss: 0.5936, Val Accuracy: 73.08%
# Epoch 10/20, Train Loss: 0.6176, Train Accuracy: 64.84%, Val Loss: 0.5691, Val Accuracy: 73.08%
# Epoch 11/20, Train Loss: 0.5973, Train Accuracy: 71.25%, Val Loss: 0.5546, Val Accuracy: 73.08%
# Epoch 12/20, Train Loss: 0.6073, Train Accuracy: 70.15%, Val Loss: 0.5596, Val Accuracy: 73.08%
# Epoch 13/20, Train Loss: 0.5900, Train Accuracy: 71.43%, Val Loss: 0.5388, Val Accuracy: 73.08%
# Epoch 14/20, Train Loss: 0.6036, Train Accuracy: 71.79%, Val Loss: 0.5287, Val Accuracy: 73.08%
# Epoch 15/20, Train Loss: 0.5841, Train Accuracy: 72.16%, Val Loss: 0.5454, Val Accuracy: 73.08%
# Epoch 16/20, Train Loss: 0.5855, Train Accuracy: 76.01%, Val Loss: 0.5286, Val Accuracy: 73.08%
# Epoch 17/20, Train Loss: 0.5790, Train Accuracy: 73.63%, Val Loss: 0.5046, Val Accuracy: 73.72%
# Epoch 18/20, Train Loss: 0.5633, Train Accuracy: 73.08%, Val Loss: 0.4958, Val Accuracy: 73.72%
# Epoch 19/20, Train Loss: 0.5933, Train Accuracy: 75.09%, Val Loss: 0.4844, Val Accuracy: 74.36%
# Epoch 20/20, Train Loss: 0.5307, Train Accuracy: 78.02%, Val Loss: 0.4943, Val Accuracy: 74.36%

# %%
# Φόρτωση του καλύτερου μοντέλου
best_model = CNN(num_classes=len(np.unique(y_train)), activation_fn='ReLU')  # Χρησιμοποιήστε τα ίδια χαρακτηριστικά του μοντέλου που είχατε πριν
best_model.load_state_dict(torch.load('best_model.pth'))  # Φορτώνουμε το state dict από το αρχείο

# Ορισμός του criterion
criterion = torch.nn.CrossEntropyLoss()

# Επαναφορά του μοντέλου σε "evaluation" mode
best_model.eval()

# Υπολογισμός του Test Loss και Test Accuracy (χωρίς να το εμφανίσουμε στα γραφήματα)
with torch.no_grad():
    test_outputs = best_model(X_test_tensor)  # Υπολογισμός εξόδου για το test set
    test_loss = criterion(test_outputs, torch.tensor(y_test_encoded, dtype=torch.long)).item()  # Υπολογισμός του Test Loss
    _, predicted = torch.max(test_outputs, 1)
    test_accuracy = (predicted == torch.tensor(y_test_encoded, dtype=torch.long)).sum().item() / len(y_test_encoded) * 100

# Εκτύπωση των βέλτιστων υπερπαραμέτρων
# Αν δεν έχετε μεταβλητή με τις βέλτιστες υπερπαραμέτρους, ορίστε την εδώ (π.χ. από το καλύτερο run)
# ΘΕΛΕΙ ΑΛΛΑΓΗ !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
best_hyperparameters = {
    'learning_rate': 0.001,
    'activation_fn': 'ReLU',
    'weight_decay': 0.01
}
print(f'Best Hyperparameters: {best_hyperparameters}')
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')

# Αποθήκευση των αποτελεσμάτων στο best_result dictionary
best_result = {
    'train_losses': train_losses,  # Απώλειες για το train set κατά την εκπαίδευση
    'val_losses': val_losses,      # Απώλειες για το validation set κατά την εκπαίδευση
    'train_accuracies': train_accuracies,  # Ακρίβεια για το train set κατά την εκπαίδευση
    'val_accuracies': val_accuracies,      # Ακρίβεια για το validation set κατά την εκπαίδευση
}

# Οπτικοποίηση των αποτελεσμάτων χωρίς το Test Loss και Test Accuracy
plt.figure(figsize=(12, 6))

# Γράφημα για τις Απώλειες του καλύτερου μοντέλου
plt.subplot(1, 2, 1)
plt.plot(range(len(best_result['train_losses'])), best_result['train_losses'], label='Train Loss', color='red')
plt.plot(range(len(best_result['val_losses'])), best_result['val_losses'], label='Validation Loss', color='blue')
plt.title(f'Losses for Best Model', pad=20)  # Προσθήκη padding στον τίτλο
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Ορισμός του άξονα x ώστε να ξεκινά από το 0
plt.xlim(0, len(best_result['train_losses'])-1)
plt.ylim(min(train_losses + val_losses) - 0.1, max(train_losses + val_losses) + 0.1)

# Γράφημα για τις Ακρίβειες του καλύτερου μοντέλου
plt.subplot(1, 2, 2)
plt.plot(range(len(best_result['train_accuracies'])), best_result['train_accuracies'], label='Train Accuracy', color='green')
plt.plot(range(len(best_result['val_accuracies'])), best_result['val_accuracies'], label='Validation Accuracy', color='orange')
plt.title(f'Accuracies for Best Model', pad=20)  # Προσθήκη padding στον τίτλο
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Ορισμός του άξονα x ώστε να ξεκινά από το 0
plt.xlim(0, len(best_result['train_accuracies'])-1)
plt.ylim(min(train_accuracies + val_accuracies) - 0.05, max(train_accuracies + val_accuracies) + 0.05)

# Χρήση του `subplots_adjust` για να αυξήσεις την απόσταση μεταξύ των υποπλοτ
plt.subplots_adjust(wspace=0.4, hspace=0.4)

plt.show()
# Out:
# Best Hyperparameters: {'learning_rate': 0.001, 'activation_fn': 'ReLU', 'weight_decay': 0.01}
# Test Loss: 0.6806, Test Accuracy: 30.77%

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize


# Μεταφορά του μοντέλου στην ίδια συσκευή
best_model.to(device)

# Συνάρτηση για την εκτύπωση του classification report και της confusion matrix
def evaluate_model(model, X_data_tensor, y_data_tensor, class_names, device):
    model.eval()  # Θέτουμε το μοντέλο σε κατάσταση αξιολόγησης
    with torch.no_grad():
        # Στείλε τα δεδομένα στην ίδια συσκευή με το μοντέλο
        X_data_tensor = X_data_tensor.to(device)
        y_data_tensor = y_data_tensor.to(device)

        # Υπολογισμός εξόδου
        outputs = model(X_data_tensor)
        _, predicted = torch.max(outputs, 1)

    # Μεταφορά των προβλέψεων και των αληθινών ετικετών στη CPU
    y_pred = predicted.cpu().numpy()
    y_true = y_data_tensor.cpu().numpy()

    # Εκτύπωση Classification Report
    print(classification_report(y_true, y_pred, target_names=class_names))

    # Confusion Matrix
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title("Confusion Matrix")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()

# Συνάρτηση για την δημιουργία της ROC Curve
def plot_roc_curve(model, X_test_tensor, y_test_encoded, class_names, device):
    # Binarize the true labels for ROC
    y_test_bin = label_binarize(y_test_encoded, classes=np.arange(len(class_names)))

    # Move data to device
    X_test_tensor = X_test_tensor.to(device)
    y_test_encoded = torch.tensor(y_test_encoded, dtype=torch.long).to(device)

    with torch.no_grad():
        outputs = model(X_test_tensor)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()

    plt.figure(figsize=(8, 6))
    if len(class_names) == 2:
        # Binary classification: plot only one ROC curve (for class 1)
        fpr, tpr, _ = roc_curve(y_test_bin.ravel(), probs[:, 1])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{class_names[1]} (AUC = {roc_auc:.2f})')
    else:
        # Multiclass case
        for i in range(len(class_names)):
            fpr, tpr, _ = roc_curve(y_test_bin[:, i], probs[:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.title('ROC Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right', bbox_to_anchor=(1.05, 1))
    plt.tight_layout()
    plt.show()

# Εκτίμηση του μοντέλου για train, val και test set
class_names = [str(c) for c in label_encoder.classes_]

# Αξιολόγηση στο Train Set
print("Classification Report for Train Set:")
evaluate_model(best_model, X_train_tensor, torch.tensor(y_train_encoded, dtype=torch.long), class_names, device)

# Αξιολόγηση στο Validation Set
print("Classification Report for Validation Set:")
evaluate_model(best_model, X_val_tensor, torch.tensor(y_val_encoded, dtype=torch.long), class_names, device)

# Αξιολόγηση στο Test Set
print("Classification Report for Test Set:")
evaluate_model(best_model, X_test_tensor, torch.tensor(y_test_encoded, dtype=torch.long), class_names, device)

# Εκτύπωση ROC Curve
plot_roc_curve(best_model, X_test_tensor, y_test_encoded, class_names, device)
# Out:
# Classification Report for Train Set:
#               precision    recall  f1-score   support
#
#            0       0.29      1.00      0.45       147
#            1       1.00      0.10      0.17       399
#
#     accuracy                           0.34       546
#    macro avg       0.64      0.55      0.31       546
# weighted avg       0.81      0.34      0.25       546
# Classification Report for Validation Set:
#               precision    recall  f1-score   support
#
#            0       0.29      0.98      0.45        42
#            1       0.93      0.11      0.20       114
#
#     accuracy                           0.35       156
#    macro avg       0.61      0.55      0.32       156
# weighted avg       0.76      0.35      0.27       156
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#            0       0.28      1.00      0.44        21
#            1       1.00      0.05      0.10        57
#
#     accuracy                           0.31        78
#    macro avg       0.64      0.53      0.27        78
# weighted avg       0.81      0.31      0.19        78
